# %%
# import statements and setup
import seaborn as sns 
# %matplotlib inline

# %%
# seaborn/matplotlib plotting or numeric work
tips = sns.load_dataset('tips')

# %%
# code cell
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# seaborn/matplotlib plotting or numeric work
sns.distplot(tips['total_bill'])
# Safe to ignore warnings
# Out:
# C:\Users\alihn\AppData\Local\Temp\ipykernel_25032\1093071496.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['total_bill'])
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# seaborn/matplotlib plotting or numeric work
sns.distplot(tips['total_bill'],kde=False,bins=30)
# Out:
# C:\Users\alihn\AppData\Local\Temp\ipykernel_25032\1274391954.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['total_bill'],kde=False,bins=30)
# <Axes: xlabel='total_bill'>

# %%
# seaborn/matplotlib plotting or numeric work
sns.jointplot(x='total_bill',y='tip',data=tips,kind='scatter')

# %%
# seaborn/matplotlib plotting or numeric work
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex')

# %%
# seaborn/matplotlib plotting or numeric work
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg')

# %%
# seaborn/matplotlib plotting or numeric work
sns.pairplot(tips)

# %%
# seaborn/matplotlib plotting or numeric work
sns.pairplot(tips,hue='sex',palette='coolwarm')

# %%
# seaborn/matplotlib plotting or numeric work
sns.rugplot(tips['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>

# %%
# import statements and setup
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

#Create dataset
dataset = np.random.randn(25)

# Create another rugplot
sns.rugplot(dataset);

# Set up the x-axis for the plot
x_min = dataset.min() - 2
x_max = dataset.max() + 2

# 100 equally spaced points from x_min to x_max
x_axis = np.linspace(x_min,x_max,100)

# Set up the bandwidth, for info on this:
url = 'http://en.wikipedia.org/wiki/Kernel_density_estimation#Practical_estimation_of_the_bandwidth'

bandwidth = ((4*dataset.std()**5)/(3*len(dataset)))**.2


# Create an empty kernel list
kernel_list = []

# Plot each basis function
for data_point in dataset:
    
    # Create a kernel for each point and append to list
    kernel = stats.norm(data_point,bandwidth).pdf(x_axis)
    kernel_list.append(kernel)
    
    #Scale for plotting
    kernel = kernel / kernel.max()
    kernel = kernel * .4
    plt.plot(x_axis,kernel,color = 'grey',alpha=0.5)

plt.ylim(0,1)
# Out:
# (0.0, 1.0)

# %%
# To get the kde plot we can sum these basis functions.

# Plot the sum of the basis function
sum_of_kde = np.sum(kernel_list,axis=0)

# Plot figure
fig = plt.plot(x_axis,sum_of_kde,color='indianred')

# Add the initial rugplot
sns.rugplot(dataset,c = 'indianred')

# Get rid of y-tick marks
plt.yticks([])

# Set title
plt.suptitle("Sum of the Basis Functions")
# Out:
# Text(0.5, 0.98, 'Sum of the Basis Functions')

# %%
# seaborn/matplotlib plotting or numeric work
sns.kdeplot(tips['total_bill'])
sns.rugplot(tips['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# seaborn/matplotlib plotting or numeric work
sns.kdeplot(tips['tip'])
sns.rugplot(tips['tip'])
# Out:
# <Axes: xlabel='tip', ylabel='Density'>

# %%
# import statements and setup
import seaborn as sns
# %matplotlib inline

# %%
# seaborn/matplotlib plotting or numeric work
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# seaborn/matplotlib plotting or numeric work
sns.barplot(x='sex',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
# import statements and setup
import numpy as np

# %%
# seaborn/matplotlib plotting or numeric work
sns.barplot(x='sex',y='total_bill',data=tips,estimator=np.std)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
# seaborn/matplotlib plotting or numeric work
sns.countplot(x='sex',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
# seaborn/matplotlib plotting or numeric work
sns.boxplot(x="day", y="total_bill", data=tips,palette='rainbow')
# Out:
# C:\Users\alihn\AppData\Local\Temp\ipykernel_25032\4016517352.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="day", y="total_bill", data=tips,palette='rainbow')
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# Can do entire dataframe with orient='h'
sns.boxplot(data=tips,palette='rainbow',orient='h')
# Out:
# <Axes: >

# %%
# seaborn/matplotlib plotting or numeric work
sns.boxplot(x="day", y="total_bill", hue="smoker",data=tips, palette="coolwarm")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# seaborn/matplotlib plotting or numeric work
sns.violinplot(x="day", y="total_bill", data=tips,palette='rainbow')
# Out:
# C:\Users\alihn\AppData\Local\Temp\ipykernel_25032\2751363601.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="day", y="total_bill", data=tips,palette='rainbow')
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# seaborn/matplotlib plotting or numeric work
sns.violinplot(x="day", y="total_bill", data=tips,hue='sex',palette='Set1')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# seaborn/matplotlib plotting or numeric work
sns.violinplot(x="day", y="total_bill", data=tips,hue='sex',split=True,palette='Set1')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# seaborn/matplotlib plotting or numeric work
sns.stripplot(x="day", y="total_bill", data=tips, palette='rainbow')
# Out:
# C:\Users\alihn\AppData\Local\Temp\ipykernel_25032\1524878028.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(x="day", y="total_bill", data=tips, palette='rainbow')
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# seaborn/matplotlib plotting or numeric work
sns.stripplot(x="day", y="total_bill", data=tips,jitter=True, palette='rainbow')
# Out:
# C:\Users\alihn\AppData\Local\Temp\ipykernel_25032\263483729.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(x="day", y="total_bill", data=tips,jitter=True, palette='rainbow')
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# seaborn/matplotlib plotting or numeric work
sns.stripplot(x="day", y="total_bill", data=tips,jitter=True,hue='sex',palette='Set1')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# seaborn/matplotlib plotting or numeric work
sns.stripplot(x="day", y="total_bill", data=tips,jitter=True,hue='sex',palette='Set1',dodge=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# seaborn/matplotlib plotting or numeric work
sns.swarmplot(x="day", y="total_bill", data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# seaborn/matplotlib plotting or numeric work
sns.violinplot(x="tip", y="day", data=tips,palette='rainbow')
sns.swarmplot(x="tip", y="day", data=tips,color='black',size=3)
# Out:
# C:\Users\alihn\AppData\Local\Temp\ipykernel_25032\734697897.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="tip", y="day", data=tips,palette='rainbow')
# <Axes: xlabel='tip', ylabel='day'>

# %%
# seaborn/matplotlib plotting or numeric work
sns.catplot(x='sex',y='total_bill',data=tips,kind='bar')

# %%
# import statements and setup
import seaborn as sns
# %matplotlib inline

# %%
# seaborn/matplotlib plotting or numeric work
flights = sns.load_dataset('flights')
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 flights = sns.load_dataset('flights')
#
# File ~\AppData\Roaming\Python\Python314\site-packages\seaborn\utils.py:574, in load_dataset(name, cache, data_home, **kws)
#     572         if name not in get_dataset_names():
#     573             raise ValueError(f"'{name}' is not one of the example datasets.")
# --> 574         urlretrieve(url, cache_path)
#     575     full_path = cache_path
#     576 else:
#
# File c:\Python314\Lib\urllib\request.py:212, in urlretrieve(url, filename, reporthook, data)
#     195 """
#     196 Retrieve a URL into a temporary location on disk.
#     197
#    (...)    208 data file as well as the resulting HTTPMessage object.
#     209 """
#     210 url_type, path = _splittype(url)
# --> 212 with contextlib.closing(urlopen(url, data)) as fp:
# ...

# %%
# seaborn/matplotlib plotting or numeric work
tips = sns.load_dataset('tips')

# %%
# code cell
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# code cell
flights.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 flights.head()
#
# NameError: name 'flights' is not defined

# %%
# code cell
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Matrix form for correlation data
tips.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 2
#       1 # Matrix form for correlation data
# ----> 2 tips.corr()
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\frame.py:13117, in DataFrame.corr(self, method, min_periods, numeric_only)
#   13115 cols = data.columns
#   13116 idx = cols.copy()
# > 13117 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   13119 if method == "pearson":
#   13120     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\frame.py:2081, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2079 if dtype is not None:
#    2080     dtype = np.dtype(dtype)
# -> 2081 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2082 if result.dtype is not dtype:
#    2083     result = np.asarray(result, dtype=dtype)
# ...

# %%
# seaborn/matplotlib plotting or numeric work
sns.heatmap(tips.corr())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 sns.heatmap(tips.corr())
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\frame.py:13117, in DataFrame.corr(self, method, min_periods, numeric_only)
#   13115 cols = data.columns
#   13116 idx = cols.copy()
# > 13117 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   13119 if method == "pearson":
#   13120     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\frame.py:2081, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2079 if dtype is not None:
#    2080     dtype = np.dtype(dtype)
# -> 2081 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2082 if result.dtype is not dtype:
#    2083     result = np.asarray(result, dtype=dtype)
#
# ...

# %%
# seaborn/matplotlib plotting or numeric work
sns.heatmap(tips.corr(),cmap='coolwarm',annot=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 sns.heatmap(tips.corr(),cmap='coolwarm',annot=True)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\frame.py:13117, in DataFrame.corr(self, method, min_periods, numeric_only)
#   13115 cols = data.columns
#   13116 idx = cols.copy()
# > 13117 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   13119 if method == "pearson":
#   13120     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\frame.py:2081, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2079 if dtype is not None:
#    2080     dtype = np.dtype(dtype)
# -> 2081 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2082 if result.dtype is not dtype:
#    2083     result = np.asarray(result, dtype=dtype)
#
# ...

# %%
# code cell
flights.pivot_table(values='passengers',index='month',columns='year')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 flights.pivot_table(values='passengers',index='month',columns='year')
#
# NameError: name 'flights' is not defined

# %%
# code cell
pvflights = flights.pivot_table(values='passengers',index='month',columns='year')
sns.heatmap(pvflights)

# %%
# seaborn/matplotlib plotting or numeric work
sns.heatmap(pvflights,cmap='magma',linecolor='white',linewidths=1)

# %%
# seaborn/matplotlib plotting or numeric work
sns.clustermap(pvflights)

# %%
# More options to get the information a little clearer like normalization
sns.clustermap(pvflights,standard_scale=1)

# %%
# import statements and setup
import seaborn as sns
# %matplotlib inline

# %%
# seaborn/matplotlib plotting or numeric work
tips = sns.load_dataset('tips')

# %%
# code cell
tips.head()

# %%
# seaborn/matplotlib plotting or numeric work
sns.lmplot(x='total_bill',y='tip',data=tips)

# %%
# seaborn/matplotlib plotting or numeric work
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex')

# %%
# seaborn/matplotlib plotting or numeric work
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',palette='coolwarm')

# %%
# seaborn/matplotlib plotting or numeric work
sns.lmplot(x='total_bill',y='tip',data=tips,col='sex')

# %%
# seaborn/matplotlib plotting or numeric work
sns.lmplot(x="total_bill", y="tip", row="sex", col="time",data=tips)

# %%
# seaborn/matplotlib plotting or numeric work
sns.lmplot(x='total_bill',y='tip',data=tips,col='day',hue='sex',palette='coolwarm')

# %%
# seaborn/matplotlib plotting or numeric work
sns.lmplot(x='total_bill',y='tip',data=tips,col='day',hue='sex',palette='coolwarm',
          aspect=0.6,height=8)
